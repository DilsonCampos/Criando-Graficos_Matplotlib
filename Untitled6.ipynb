# %% [markdown]
# <a href="https://colab.research.google.com/github/DilsonCampos/Criando-Gr-ficos1_Matplotlib/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot();

# %%
import matplotlib.pyplot as plt
import numpy as np
point_y = np.array ([3, 8, 1, 10])
plt.plot(point_y, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
point_y = np.array ([3, 8, 1, 10])
plt.plot(point_y, 'o:g', ms = 21)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
point_y = np.array ([3, 8, 1, 10])
plt.plot(point_y, marker = 'o', ms = 10, mec = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
point_y = np.array ([3, 8, 1, 10])
plt.plot(point_y, marker = 'o', ms = 30, mfc = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
point_y = np.array ([3, 8, 1, 10])
plt.plot(point_y, marker = 'o', ms = 21, mec = 'g', mfc = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
point_y = np.array ([3, 8, 1, 10])
plt.plot(point_y, marker = 'o', ms = 21, mec = 'r', mfc = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
point_y = np.array ([3, 8, 1, 10])
plt.plot(point_y, linestyle  = 'dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
point_y = np.array ([3, 8, 1, 10])
plt.plot(point_y, ls  = 'dashdot')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
point_y = np.array ([3, 8, 1, 10])
plt.plot(point_y, c = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
point_y = np.array ([3, 8, 1, 10])
plt.plot(point_y, c = '#FFD700')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
point_y = np.array ([3, 8, 1, 10])
plt.plot(point_y, linewidth = '16.3')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
point_y = np.array ([3, 8, 1, 10])
plt.plot(point_y, linewidth = '20.3')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
point_y = np.array ([2, 8, 4, 10])
plt.plot(point_y, c = '#00ff83', lw = '9')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
first_line = np.array([1, 8, 4, 15])
secound_line = np.array([6, 2, 12, 4])
plt.plot(first_line, c = 'r')
plt.plot(secound_line, c = 'g')
plt.show()
